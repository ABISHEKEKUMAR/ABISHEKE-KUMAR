# %%
import pandas as pd
import numpy as np
file=pd.read_csv("/Student.csv")
df=pd.DataFrame(file)

# %%
df
# Out:
#         ID  GENDER  MARRITIAL STATUS   AGE  COMPANION  EMPLOYMENT  \
# 0      1.0     1.0               1.0  23.0        0.0         5.0
# 1      2.0     1.0               0.0  25.0        1.0         3.0
# 2      3.0     2.0               0.0  24.0        1.0         5.0
# 3      4.0     1.0               1.0  25.0        1.0         5.0
# 4      5.0     2.0               1.0  22.0        0.0         3.0
# ...    ...     ...               ...   ...        ...         ...
# 1002  64.0     1.0               1.0  25.0        1.0         2.0
# 1003  65.0     2.0               1.0  20.0        0.0         2.0
# 1004  66.0     2.0               1.0  21.0        1.0         2.0
# 1005  67.0     1.0               1.0  23.0        1.0         4.0
# 1006  68.0     1.0               0.0  21.0        1.0         2.0
#
#       TWO_FOUR_WHEELER  CINEMA_LIKES     MONEY
# 0                  0.0           1.0  690827.0
# 1                  1.0           1.0  666946.0
# 2                  1.0           2.0  872033.0
# 3                  1.0           2.0  675677.0
# 4                  1.0           2.0  699206.0
# ...                ...           ...       ...
# 1002               1.0           2.0  579222.0
# 1003               1.0           2.0  604955.0
# 1004               1.0           2.0  514313.0
# 1005               1.0           3.0  912896.0
# 1006               1.0           1.0  310000.0
#
# [1007 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1006 non-null   float64
#  1   GENDER            1006 non-null   float64
#  2   MARRITIAL STATUS  1004 non-null   float64
#  3   AGE               1005 non-null   float64
#  4   COMPANION         1004 non-null   float64
#  5   EMPLOYMENT        1006 non-null   float64
#  6   TWO_FOUR_WHEELER  1003 non-null   float64
#  7   CINEMA_LIKES      1005 non-null   float64
#  8   MONEY             1006 non-null   float64
# dtypes: float64(9)
# memory usage: 70.9 KB

# %%
df.describe()
# Out:
#                 ID       GENDER  MARRITIAL STATUS          AGE    COMPANION  \
# count  1006.000000  1006.000000       1004.000000  1005.000000  1004.000000
# mean    497.003976     1.512922          0.483068    22.679602     0.506972
# std     289.843176     0.500082          0.499962     4.366756     0.500201
# min       1.000000     1.000000          0.000000    20.000000     0.000000
# 25%     245.250000     1.000000          0.000000    21.000000     0.000000
# 50%     496.500000     2.000000          0.000000    22.000000     1.000000
# 75%     747.750000     2.000000          1.000000    24.000000     1.000000
# max    1000.000000     2.000000          1.000000    90.000000     1.000000
#
#         EMPLOYMENT  TWO_FOUR_WHEELER  CINEMA_LIKES         MONEY
# count  1006.000000       1003.000000   1005.000000  1.006000e+03
# mean      2.990060          0.525424      2.000995  7.493949e+05
# std       1.395765          0.499602      0.819945  1.713715e+05
# min       1.000000          0.000000      1.000000  1.000000e+05
# 25%       2.000000          0.000000      1.000000  6.241638e+05
# 50%       3.000000          1.000000      2.000000  7.484295e+05
# 75%       4.000000          1.000000      3.000000  8.744798e+05
# max       5.000000          1.000000      3.000000  2.000000e+06

# %%
df.drop(['ID'],axis=1,inplace=True)

# %%
df[df.duplicated()]
# Out:
#       GENDER  MARRITIAL STATUS   AGE  COMPANION  EMPLOYMENT  TWO_FOUR_WHEELER  \
# 1000     2.0               1.0  21.0        0.0         3.0               1.0
# 1001     2.0               1.0  23.0        1.0         3.0               0.0
# 1002     1.0               1.0  25.0        1.0         2.0               1.0
# 1003     2.0               1.0  20.0        0.0         2.0               1.0
# 1004     2.0               1.0  21.0        1.0         2.0               1.0
# 1005     1.0               1.0  23.0        1.0         4.0               1.0
# 1006     1.0               0.0  21.0        1.0         2.0               1.0
#
#       CINEMA_LIKES     MONEY
# 1000           1.0  705599.0
# 1001           2.0  508890.0
# 1002           2.0  579222.0
# 1003           2.0  604955.0
# 1004           2.0  514313.0
# 1005           3.0  912896.0
# 1006           1.0  310000.0

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.isna().sum()
# Out:
# GENDER              1
# MARRITIAL STATUS    3
# AGE                 2
# COMPANION           3
# EMPLOYMENT          1
# TWO_FOUR_WHEELER    4
# CINEMA_LIKES        2
# MONEY               1
# dtype: int64

# %%
df['GENDER']=df['GENDER'].astype('object')
df['MARRITIAL STATUS']=df['MARRITIAL STATUS'].astype('object')
df['COMPANION']=df['COMPANION'].astype('object')
df['TWO_FOUR_WHEELER']=df['TWO_FOUR_WHEELER'].astype('object')
df['CINEMA_LIKES']=df['CINEMA_LIKES'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GENDER            999 non-null    object
#  1   MARRITIAL STATUS  997 non-null    object
#  2   AGE               998 non-null    float64
#  3   COMPANION         997 non-null    object
#  4   EMPLOYMENT        999 non-null    float64
#  5   TWO_FOUR_WHEELER  996 non-null    object
#  6   CINEMA_LIKES      998 non-null    object
#  7   MONEY             999 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 70.3+ KB

# %%
for i in df:
    if df[i].dtype=='object':
        df[i].fillna(df[i].mode()[0],inplace=True)
    else:
        df[i].fillna(df[i].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GENDER            1000 non-null   float64
#  1   MARRITIAL STATUS  1000 non-null   float64
#  2   AGE               1000 non-null   float64
#  3   COMPANION         1000 non-null   float64
#  4   EMPLOYMENT        1000 non-null   float64
#  5   TWO_FOUR_WHEELER  1000 non-null   float64
#  6   CINEMA_LIKES      1000 non-null   float64
#  7   MONEY             1000 non-null   float64
# dtypes: float64(8)
# memory usage: 70.3 KB

# %%
import matplotlib.pyplot as mtp
import seaborn as sns
sns.pairplot(df,kind='scatter')

# %%
sns.heatmap(df,cmap='coolwarm')

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col1 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col4 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col5 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col6 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow0_col7 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col3 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col4 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow1_col7 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col1 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col4 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow2_col7 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col4 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col6 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow3_col7 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col0 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col2 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col6 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow4_col7 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col0 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col2 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col4 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow5_col7 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col3 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col5 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow6_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow7_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow7_col1 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow7_col2 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_4799738f_d4f8_11ec_b2cb_98e743200cbbrow7_col3 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;

# %%
fig,ax=mtp.subplots(2,4,figsize=(10,15))
mtp.subplot(2,4,1)
mtp.boxplot(df['GENDER'])
mtp.subplot(2,4,2)
mtp.boxplot(df['MARRITIAL STATUS'])
mtp.subplot(2,4,3)
mtp.boxplot(df['AGE'])
mtp.subplot(2,4,4)
mtp.boxplot(df['COMPANION'])
mtp.subplot(2,4,5)
mtp.boxplot(df['TWO_FOUR_WHEELER'])
mtp.subplot(2,4,6)
mtp.boxplot(df['CINEMA_LIKES'])
mtp.subplot(2,4,7)
mtp.boxplot(df['MONEY'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x163a784b880>,
#   <matplotlib.lines.Line2D at 0x163a784ba90>],
#  'caps': [<matplotlib.lines.Line2D at 0x163a784b400>,
#   <matplotlib.lines.Line2D at 0x163a7803850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x163a784b220>],
#  'medians': [<matplotlib.lines.Line2D at 0x163a7803f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x163a7803a00>],
#  'means': []}

# %%
for i in df:
    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)
    iqr=q3-q1
    lower=q1-1.5*iqr
    upper=q3+1.5*iqr
    df[i]=np.where(df[i]>upper,upper,df[i])
    df[i]=np.where(df[i]<lower,lower,df[i])

# %%
fig,ax=mtp.subplots(2,4,figsize=(10,15))
mtp.subplot(2,4,1)
mtp.boxplot(df['GENDER'])
mtp.subplot(2,4,2)
mtp.boxplot(df['MARRITIAL STATUS'])
mtp.subplot(2,4,3)
mtp.boxplot(df['AGE'])
mtp.subplot(2,4,4)
mtp.boxplot(df['COMPANION'])
mtp.subplot(2,4,5)
mtp.boxplot(df['TWO_FOUR_WHEELER'])
mtp.subplot(2,4,6)
mtp.boxplot(df['CINEMA_LIKES'])
mtp.subplot(2,4,7)
mtp.boxplot(df['MONEY'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x163a75fb850>,
#   <matplotlib.lines.Line2D at 0x163a75fb400>],
#  'caps': [<matplotlib.lines.Line2D at 0x163a75d6af0>,
#   <matplotlib.lines.Line2D at 0x163a75d6700>],
#  'boxes': [<matplotlib.lines.Line2D at 0x163a75fbd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x163a75c9850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x163a75c9640>],
#  'means': []}
